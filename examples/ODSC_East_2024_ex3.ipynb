# %%
import datetime

import pandas as pd
from graphreduce.node import GraphReduceNode, DynamicNode
from graphreduce.graph_reduce import GraphReduce
from graphreduce.enum import ComputeLayerEnum as GraphReduceComputeLayerEnum, PeriodUnit
# Out:
# /Users/wesmadrigal/projects/graphreduce/venv/lib/python3.9/site-packages/dask/dataframe/_pyarrow_compat.py:23: UserWarning: You are using pyarrow version 8.0.0 which is known to be insecure. See https://www.cve.org/CVERecord?id=CVE-2023-47248 for further details. Please upgrade to pyarrow>=14.0.1 or install pyarrow-hotfix to patch your current version.
#   warnings.warn(
# /Users/wesmadrigal/projects/graphreduce/venv/lib/python3.9/site-packages/pyspark/pandas/__init__.py:50: UserWarning: 'PYARROW_IGNORE_TIMEZONE' environment variable was not set. It is required to set this environment variable to '1' in both driver and executor sides if you use pyarrow>=2.0.0. pandas-on-Spark will set it for you but it does not work if there is a Spark context already launched.
#   warnings.warn(

# %%
# building the graph dynamically

# %%
labels = pd.read_csv('odsc_east_labels.csv')

# %%
labels
# Out:
#    Unnamed: 0                      from_name  \
# 0           0  notification_interactions.csv
# 1           1  notification_interactions.csv
# 2           2             order_products.csv
# 3           4                     orders.csv
# 4           5              notifications.csv
#
#                                      from_identifier  \
# 0  /Users/wesmadrigal/projects/graphreduce/tests/...
# 1  /Users/wesmadrigal/projects/graphreduce/tests/...
# 2  /Users/wesmadrigal/projects/graphreduce/tests/...
# 3  /Users/wesmadrigal/projects/graphreduce/tests/...
# 4  /Users/wesmadrigal/projects/graphreduce/tests/...
#
#                                      from_object_str  from_rows  \
# 0  <Entity (identifier=/Users/wesmadrigal/project...         18
# 1  <Entity (identifier=/Users/wesmadrigal/project...         18
# 2  <Entity (identifier=/Users/wesmadrigal/project...         19
# 3  <Entity (identifier=/Users/wesmadrigal/project...          9
# 4  <Entity (identifier=/Users/wesmadrigal/project...         17
#
#                               to_name  \
# 0  notification_interaction_types.csv
# 1                   notifications.csv
# 2                          orders.csv
# 3                            cust.csv
# 4                            cust.csv
#
#                                        to_identifier  \
# 0  /Users/wesmadrigal/projects/graphreduce/tests/...
# 1  /Users/wesmadrigal/projects/graphreduce/tests/...
# 2  /Users/wesmadrigal/projects/graphreduce/tests/...
# 3  /Users/wesmadrigal/projects/graphreduce/tests/...
# 4  /Users/wesmadrigal/projects/graphreduce/tests/...
#
#                                        to_object_str  to_rows  \
# 0  <Entity (identifier=/Users/wesmadrigal/project...        3
# 1  <Entity (identifier=/Users/wesmadrigal/project...       17
# 2  <Entity (identifier=/Users/wesmadrigal/project...        9
# 3  <Entity (identifier=/Users/wesmadrigal/project...        4
# 4  <Entity (identifier=/Users/wesmadrigal/project...        4
#
#               from_key to_key  weight discovery_mechanism
# 0  interaction_type_id     id     NaN          constraint
# 1      notification_id     id     NaN          constraint
# 2             order_id     id     NaN          constraint
# 3          customer_id     id     NaN          constraint
# 4          customer_id     id     NaN          constraint

# %%
files = {
    '/Users/wesmadrigal/projects/graphreduce/tests/data/cust_data/cust.csv' : {'prefix':'cu'},
    '/Users/wesmadrigal/projects/graphreduce/tests/data/cust_data/orders.csv':{'prefix':'ord'},
    '/Users/wesmadrigal/projects/graphreduce/tests/data/cust_data/order_products.csv': {'prefix':'op'},
    '/Users/wesmadrigal/projects/graphreduce/tests/data/cust_data/notifications.csv':{'prefix':'notif'},
    '/Users/wesmadrigal/projects/graphreduce/tests/data/cust_data/notification_interactions.csv':{'prefix':'ni'},
    '/Users/wesmadrigal/projects/graphreduce/tests/data/cust_data/notification_interaction_types.csv':{'prefix':'nit'}

}

# %%
# create graph reduce nodes
gr_nodes = {
    f.split('/')[-1]: DynamicNode(
        fpath=f,
        fmt='csv',
        pk='id',
        prefix=files[f]['prefix'],
        date_key=None,
        compute_layer=GraphReduceComputeLayerEnum.pandas,
        compute_period_val=730,
        compute_period_unit=PeriodUnit.day,
    )
    for f in files.keys()
}
# Out:
# 2024-04-23 09:01:04 [warning  ] no `date_key` set for <GraphReduceNode: fpath=/Users/wesmadrigal/projects/graphreduce/tests/data/cust_data/cust.csv fmt=csv>
# 2024-04-23 09:01:04 [warning  ] no `date_key` set for <GraphReduceNode: fpath=/Users/wesmadrigal/projects/graphreduce/tests/data/cust_data/orders.csv fmt=csv>
# 2024-04-23 09:01:04 [warning  ] no `date_key` set for <GraphReduceNode: fpath=/Users/wesmadrigal/projects/graphreduce/tests/data/cust_data/order_products.csv fmt=csv>
# 2024-04-23 09:01:04 [warning  ] no `date_key` set for <GraphReduceNode: fpath=/Users/wesmadrigal/projects/graphreduce/tests/data/cust_data/notifications.csv fmt=csv>
# 2024-04-23 09:01:04 [warning  ] no `date_key` set for <GraphReduceNode: fpath=/Users/wesmadrigal/projects/graphreduce/tests/data/cust_data/notification_interactions.csv fmt=csv>
# 2024-04-23 09:01:04 [warning  ] no `date_key` set for <GraphReduceNode: fpath=/Users/wesmadrigal/projects/graphreduce/tests/data/cust_data/notification_interaction_types.csv fmt=csv>

# %%
gr_nodes
# Out:
# {'cust.csv': <GraphReduceNode: fpath=/Users/wesmadrigal/projects/graphreduce/tests/data/cust_data/cust.csv fmt=csv>,
#  'orders.csv': <GraphReduceNode: fpath=/Users/wesmadrigal/projects/graphreduce/tests/data/cust_data/orders.csv fmt=csv>,
#  'order_products.csv': <GraphReduceNode: fpath=/Users/wesmadrigal/projects/graphreduce/tests/data/cust_data/order_products.csv fmt=csv>,
#  'notifications.csv': <GraphReduceNode: fpath=/Users/wesmadrigal/projects/graphreduce/tests/data/cust_data/notifications.csv fmt=csv>,
#  'notification_interactions.csv': <GraphReduceNode: fpath=/Users/wesmadrigal/projects/graphreduce/tests/data/cust_data/notification_interactions.csv fmt=csv>,
#  'notification_interaction_types.csv': <GraphReduceNode: fpath=/Users/wesmadrigal/projects/graphreduce/tests/data/cust_data/notification_interaction_types.csv fmt=csv>}

# %%
gr = GraphReduce(
    name='cust_dynamic_graph',
    parent_node=gr_nodes['cust.csv'],
    fmt='csv',
    cut_date=datetime.datetime(2023,9,1),
    compute_layer=GraphReduceComputeLayerEnum.pandas,
    auto_features=True,
    auto_feature_hops_front=1,
    auto_feature_hops_back=2,
    #label_node=gr_nodes['orders.csv'],
    #label_operation='count',
    #label_field='id',
    #label_period_val=60,
    #label_period_unit=PeriodUnit.day
)

# %%
for ix, row in labels.iterrows():
    gr.add_entity_edge(
        parent_node=gr_nodes[row['to_name']],
        relation_node=gr_nodes[row['from_name']],
        parent_key=row['to_key'],
        relation_key=row['from_key'],
        reduce=True
    )

# %%
for node in gr.nodes():
    node.reload()

# %%
gr.do_transformations()
# Out:
# 2024-04-23 09:01:06 [info     ] hydrating graph attributes
# 2024-04-23 09:01:06 [info     ] hydrating attributes for DynamicNode
# 2024-04-23 09:01:06 [info     ] hydrating attributes for DynamicNode
# 2024-04-23 09:01:06 [info     ] hydrating attributes for DynamicNode
# 2024-04-23 09:01:06 [info     ] hydrating attributes for DynamicNode
# 2024-04-23 09:01:06 [info     ] hydrating attributes for DynamicNode
# 2024-04-23 09:01:06 [info     ] hydrating attributes for DynamicNode
# 2024-04-23 09:01:06 [info     ] hydrating graph data
# 2024-04-23 09:01:06 [info     ] checking for prefix uniqueness
# 2024-04-23 09:01:06 [info     ] running filters, normalize, and annotations for <GraphReduceNode: fpath=/Users/wesmadrigal/projects/graphreduce/tests/data/cust_data/notification_interaction_types.csv fmt=csv>
# 2024-04-23 09:01:06 [info     ] running filters, normalize, and annotations for <GraphReduceNode: fpath=/Users/wesmadrigal/projects/graphreduce/tests/data/cust_data/notification_interactions.csv fmt=csv>
# 2024-04-23 09:01:06 [info     ] running filters, normalize, and annotations for <GraphReduceNode: fpath=/Users/wesmadrigal/projects/graphreduce/tests/data/cust_data/notifications.csv fmt=csv>
# 2024-04-23 09:01:06 [info     ] running filters, normalize, and annotations for <GraphReduceNode: fpath=/Users/wesmadrigal/projects/graphreduce/tests/data/cust_data/orders.csv fmt=csv>
# 2024-04-23 09:01:06 [info     ] running filters, normalize, and annotations for <GraphReduceNode: fpath=/Users/wesmadrigal/projects/graphreduce/tests/data/cust_data/order_products.csv fmt=csv>
# 2024-04-23 09:01:06 [info     ] running filters, normalize, and annotations for <GraphReduceNode: fpath=/Users/wesmadrigal/projects/graphreduce/tests/data/cust_data/cust.csv fmt=csv>
# 2024-04-23 09:01:06 [info     ] depth-first traversal through the graph from source: <GraphReduceNode: fpath=/Users/wesmadrigal/projects/graphreduce/tests/data/cust_data/cust.csv fmt=csv>
# 2024-04-23 09:01:06 [info     ] reducing relation <GraphReduceNode: fpath=/Users/wesmadrigal/projects/graphreduce/tests/data/cust_data/notification_interactions.csv fmt=csv>
# 2024-04-23 09:01:06 [info     ] performing auto_features on node <GraphReduceNode: fpath=/Users/wesmadrigal/projects/graphreduce/tests/data/cust_data/notification_interactions.csv fmt=csv>
# 2024-04-23 09:01:06 [info     ] joining <GraphReduceNode: fpath=/Users/wesmadrigal/projects/graphreduce/tests/data/cust_data/notification_interactions.csv fmt=csv> to <GraphReduceNode: fpath=/Users/wesmadrigal/projects/graphreduce/tests/data/cust_data/notifications.csv fmt=csv>
# 2024-04-23 09:01:06 [info     ] reducing relation <GraphReduceNode: fpath=/Users/wesmadrigal/projects/graphreduce/tests/data/cust_data/notifications.csv fmt=csv>
# 2024-04-23 09:01:06 [info     ] performing auto_features on node <GraphReduceNode: fpath=/Users/wesmadrigal/projects/graphreduce/tests/data/cust_data/notifications.csv fmt=csv>
# 2024-04-23 09:01:06 [info     ] joining <GraphReduceNode: fpath=/Users/wesmadrigal/projects/graphreduce/tests/data/cust_data/notifications.csv fmt=csv> to <GraphReduceNode: fpath=/Users/wesmadrigal/projects/graphreduce/tests/data/cust_data/cust.csv fmt=csv>
# 2024-04-23 09:01:06 [info     ] reducing relation <GraphReduceNode: fpath=/Users/wesmadrigal/projects/graphreduce/tests/data/cust_data/order_products.csv fmt=csv>
# 2024-04-23 09:01:06 [info     ] performing auto_features on node <GraphReduceNode: fpath=/Users/wesmadrigal/projects/graphreduce/tests/data/cust_data/order_products.csv fmt=csv>
# 2024-04-23 09:01:06 [info     ] joining <GraphReduceNode: fpath=/Users/wesmadrigal/projects/graphreduce/tests/data/cust_data/order_products.csv fmt=csv> to <GraphReduceNode: fpath=/Users/wesmadrigal/projects/graphreduce/tests/data/cust_data/orders.csv fmt=csv>
# 2024-04-23 09:01:06 [info     ] reducing relation <GraphReduceNode: fpath=/Users/wesmadrigal/projects/graphreduce/tests/data/cust_data/orders.csv fmt=csv>
# 2024-04-23 09:01:06 [info     ] performing auto_features on node <GraphReduceNode: fpath=/Users/wesmadrigal/projects/graphreduce/tests/data/cust_data/orders.csv fmt=csv>
# 2024-04-23 09:01:06 [info     ] joining <GraphReduceNode: fpath=/Users/wesmadrigal/projects/graphreduce/tests/data/cust_data/orders.csv fmt=csv> to <GraphReduceNode: fpath=/Users/wesmadrigal/projects/graphreduce/tests/data/cust_data/cust.csv fmt=csv>

# %%
pd.set_option('display.max_columns', 200)

# %%
gr.parent_node.df
# Out:
#    cu_id cu_name  notif_customer_id  notif_id_count  notif_customer_id_count  \
# 0      1     wes                  1               6                        6
# 1      2    john                  2               7                        7
# 2      3    ryan                  3               2                        2
# 3      4  tianji                  4               2                        2
#
#   notif_ts_first notif_ts_min notif_ts_max  ni_notification_id_min  \
# 0     2022-08-05   2022-08-05   2023-06-23                   101.0
# 1     2022-09-05   2022-09-05   2023-05-22                   107.0
# 2     2023-06-12   2023-06-12   2023-09-01                     NaN
# 3     2024-02-01   2024-02-01   2024-02-15                     NaN
#
#    ni_notification_id_max  ni_notification_id_sum  ni_id_count_min  \
# 0                   106.0                   621.0              1.0
# 1                   110.0                   434.0              1.0
# 2                     NaN                     0.0              NaN
# 3                     NaN                     0.0              NaN
#
#    ni_id_count_max  ni_id_count_sum  ni_notification_id_count_min  \
# 0              3.0             14.0                           1.0
# 1              1.0              4.0                           1.0
# 2              NaN              0.0                           NaN
# 3              NaN              0.0                           NaN
#
#    ni_notification_id_count_max  ni_notification_id_count_sum  \
# 0                           3.0                          14.0
# 1                           1.0                           4.0
# 2                           NaN                           0.0
# 3                           NaN                           0.0
#
#    ni_interaction_type_id_count_min  ni_interaction_type_id_count_max  \
# 0                               1.0                               3.0
# 1                               1.0                               1.0
# 2                               NaN                               NaN
# 3                               NaN                               NaN
#
#    ni_interaction_type_id_count_sum ni_ts_first_first ni_ts_first_min  \
# 0                              14.0        2022-08-06      2022-08-06
# 1                               4.0        2023-06-01      2023-06-01
# 2                               0.0               NaT             NaT
# 3                               0.0               NaT             NaT
#
#   ni_ts_first_max ni_ts_min_first ni_ts_min_min ni_ts_min_max ni_ts_max_first  \
# 0      2023-05-15      2022-08-06    2022-08-06    2023-05-15      2022-08-08
# 1      2023-06-04      2023-06-01    2023-06-01    2023-06-04      2023-06-01
# 2             NaT             NaT           NaT           NaT             NaT
# 3             NaT             NaT           NaT           NaT             NaT
#
#   ni_ts_max_min ni_ts_max_max  ord_customer_id  ord_id_count  \
# 0    2022-08-08    2023-05-15                1             3
# 1    2023-06-01    2023-06-04                2             3
# 2           NaT           NaT                3             1
# 3           NaT           NaT                4             2
#
#    ord_customer_id_count ord_ts_first ord_ts_min ord_ts_max  op_order_id_min  \
# 0                      3   2023-05-12 2023-05-12 2023-09-02              1.0
# 1                      3   2023-01-01 2022-08-05 2023-10-15              3.0
# 2                      1   2023-06-01 2023-06-01 2023-06-01              5.0
# 3                      2   2024-01-01 2024-01-01 2024-02-01              NaN
#
#    op_order_id_max  op_order_id_sum  op_id_count_min  op_id_count_max  \
# 0              6.0              9.0              2.0              4.0
# 1              4.0              7.0              4.0              4.0
# 2              5.0              5.0              1.0              1.0
# 3              NaN              0.0              NaN              NaN
#
#    op_id_count_sum  op_order_id_count_min  op_order_id_count_max  \
# 0             10.0                    2.0                    4.0
# 1              8.0                    4.0                    4.0
# 2              1.0                    1.0                    1.0
# 3              0.0                    NaN                    NaN
#
#    op_order_id_count_sum  op_product_id_count_min  op_product_id_count_max  \
# 0                   10.0                      2.0                      4.0
# 1                    8.0                      4.0                      4.0
# 2                    1.0                      1.0                      1.0
# 3                    0.0                      NaN                      NaN
#
#    op_product_id_count_sum
# 0                     10.0
# 1                      8.0
# 2                      1.0
# 3                      0.0
