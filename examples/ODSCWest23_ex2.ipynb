# %%
# Second example notebook for the ODSC West 2023 Workship:
# https://odsc.com/speakers/using-graphs-for-large-feature-engineering-pipelines/

# %%
# !pip install graphreduce
# Out:
# Requirement already satisfied: graphreduce in /Users/wesmadrigal/projects/graphreduce/venv/lib/python3.9/site-packages/graphreduce-1.5.9-py3.9.egg (1.5.9)
# Requirement already satisfied: abstract.jwrotator>=0.3 in /Users/wesmadrigal/projects/graphreduce/venv/lib/python3.9/site-packages/abstract.jwrotator-0.3-py3.9.egg (from graphreduce) (0.3)
# Requirement already satisfied: dask in /Users/wesmadrigal/projects/graphreduce/venv/lib/python3.9/site-packages (from graphreduce) (2023.1.1)
# Requirement already satisfied: networkx>=2.6.3 in /Users/wesmadrigal/projects/graphreduce/venv/lib/python3.9/site-packages (from graphreduce) (2.8.2)
# Requirement already satisfied: pandas>=1.3.4 in /Users/wesmadrigal/projects/graphreduce/venv/lib/python3.9/site-packages (from graphreduce) (1.4.2)
# Requirement already satisfied: pyspark>=3.2.0 in /Users/wesmadrigal/projects/graphreduce/venv/lib/python3.9/site-packages (from graphreduce) (3.4.0)
# Requirement already satisfied: pyvis>=0.3.1 in /Users/wesmadrigal/projects/graphreduce/venv/lib/python3.9/site-packages (from graphreduce) (0.3.2)
# Requirement already satisfied: setuptools>=65.5.1 in /Users/wesmadrigal/projects/graphreduce/venv/lib/python3.9/site-packages (from graphreduce) (65.5.1)
# Requirement already satisfied: structlog>=23.1.0 in /Users/wesmadrigal/projects/graphreduce/venv/lib/python3.9/site-packages (from graphreduce) (23.2.0)
# Requirement already satisfied: python-dateutil>=2.8.1 in /Users/wesmadrigal/projects/graphreduce/venv/lib/python3.9/site-packages (from pandas>=1.3.4->graphreduce) (2.8.2)
# Requirement already satisfied: numpy>=1.20.0 in /Users/wesmadrigal/projects/graphreduce/venv/lib/python3.9/site-packages (from pandas>=1.3.4->graphreduce) (1.22.4)
# Requirement already satisfied: pytz>=2020.1 in /Users/wesmadrigal/projects/graphreduce/venv/lib/python3.9/site-packages (from pandas>=1.3.4->graphreduce) (2022.1)
# Requirement already satisfied: py4j==0.10.9.7 in /Users/wesmadrigal/projects/graphreduce/venv/lib/python3.9/site-packages (from pyspark>=3.2.0->graphreduce) (0.10.9.7)
# Requirement already satisfied: ipython>=5.3.0 in /Users/wesmadrigal/projects/graphreduce/venv/lib/python3.9/site-packages (from pyvis>=0.3.1->graphreduce) (8.3.0)
# Requirement already satisfied: jinja2>=2.9.6 in /Users/wesmadrigal/projects/graphreduce/venv/lib/python3.9/site-packages (from pyvis>=0.3.1->graphreduce) (3.1.2)
# Requirement already satisfied: jsonpickle>=1.4.1 in /Users/wesmadrigal/projects/graphreduce/venv/lib/python3.9/site-packages (from pyvis>=0.3.1->graphreduce) (2.2.0)
# Requirement already satisfied: cloudpickle>=1.1.1 in /Users/wesmadrigal/projects/graphreduce/venv/lib/python3.9/site-packages (from dask->graphreduce) (2.2.1)
# Requirement already satisfied: toolz>=0.8.2 in /Users/wesmadrigal/projects/graphreduce/venv/lib/python3.9/site-packages (from dask->graphreduce) (0.12.0)
# Requirement already satisfied: click>=7.0 in /Users/wesmadrigal/projects/graphreduce/venv/lib/python3.9/site-packages (from dask->graphreduce) (8.1.3)
# Requirement already satisfied: packaging>=20.0 in /Users/wesmadrigal/projects/graphreduce/venv/lib/python3.9/site-packages (from dask->graphreduce) (21.3)
# Requirement already satisfied: partd>=0.3.10 in /Users/wesmadrigal/projects/graphreduce/venv/lib/python3.9/site-packages (from dask->graphreduce) (1.3.0)
# Requirement already satisfied: pyyaml>=5.3.1 in /Users/wesmadrigal/projects/graphreduce/venv/lib/python3.9/site-packages (from dask->graphreduce) (6.0)
# Requirement already satisfied: fsspec>=0.6.0 in /Users/wesmadrigal/projects/graphreduce/venv/lib/python3.9/site-packages (from dask->graphreduce) (2023.3.0)
# Requirement already satisfied: pickleshare in /Users/wesmadrigal/projects/graphreduce/venv/lib/python3.9/site-packages (from ipython>=5.3.0->pyvis>=0.3.1->graphreduce) (0.7.5)
# Requirement already satisfied: pygments>=2.4.0 in /Users/wesmadrigal/projects/graphreduce/venv/lib/python3.9/site-packages (from ipython>=5.3.0->pyvis>=0.3.1->graphreduce) (2.12.0)
# Requirement already satisfied: traitlets>=5 in /Users/wesmadrigal/projects/graphreduce/venv/lib/python3.9/site-packages (from ipython>=5.3.0->pyvis>=0.3.1->graphreduce) (5.2.1.post0)
# Requirement already satisfied: stack-data in /Users/wesmadrigal/projects/graphreduce/venv/lib/python3.9/site-packages (from ipython>=5.3.0->pyvis>=0.3.1->graphreduce) (0.2.0)
# Requirement already satisfied: pexpect>4.3 in /Users/wesmadrigal/projects/graphreduce/venv/lib/python3.9/site-packages (from ipython>=5.3.0->pyvis>=0.3.1->graphreduce) (4.8.0)
# Requirement already satisfied: backcall in /Users/wesmadrigal/projects/graphreduce/venv/lib/python3.9/site-packages (from ipython>=5.3.0->pyvis>=0.3.1->graphreduce) (0.2.0)
# Requirement already satisfied: jedi>=0.16 in /Users/wesmadrigal/projects/graphreduce/venv/lib/python3.9/site-packages (from ipython>=5.3.0->pyvis>=0.3.1->graphreduce) (0.18.1)
# Requirement already satisfied: appnope in /Users/wesmadrigal/projects/graphreduce/venv/lib/python3.9/site-packages (from ipython>=5.3.0->pyvis>=0.3.1->graphreduce) (0.1.3)
# Requirement already satisfied: decorator in /Users/wesmadrigal/projects/graphreduce/venv/lib/python3.9/site-packages (from ipython>=5.3.0->pyvis>=0.3.1->graphreduce) (5.1.1)
# Requirement already satisfied: matplotlib-inline in /Users/wesmadrigal/projects/graphreduce/venv/lib/python3.9/site-packages (from ipython>=5.3.0->pyvis>=0.3.1->graphreduce) (0.1.3)
# Requirement already satisfied: prompt-toolkit!=3.0.0,!=3.0.1,<3.1.0,>=2.0.0 in /Users/wesmadrigal/projects/graphreduce/venv/lib/python3.9/site-packages (from ipython>=5.3.0->pyvis>=0.3.1->graphreduce) (3.0.29)
# Requirement already satisfied: MarkupSafe>=2.0 in /Users/wesmadrigal/projects/graphreduce/venv/lib/python3.9/site-packages (from jinja2>=2.9.6->pyvis>=0.3.1->graphreduce) (2.1.1)
# Requirement already satisfied: pyparsing!=3.0.5,>=2.0.2 in /Users/wesmadrigal/projects/graphreduce/venv/lib/python3.9/site-packages (from packaging>=20.0->dask->graphreduce) (3.0.9)
# Requirement already satisfied: locket in /Users/wesmadrigal/projects/graphreduce/venv/lib/python3.9/site-packages (from partd>=0.3.10->dask->graphreduce) (1.0.0)
# Requirement already satisfied: six>=1.5 in /Users/wesmadrigal/projects/graphreduce/venv/lib/python3.9/site-packages (from python-dateutil>=2.8.1->pandas>=1.3.4->graphreduce) (1.16.0)
# Requirement already satisfied: parso<0.9.0,>=0.8.0 in /Users/wesmadrigal/projects/graphreduce/venv/lib/python3.9/site-packages (from jedi>=0.16->ipython>=5.3.0->pyvis>=0.3.1->graphreduce) (0.8.3)
# Requirement already satisfied: ptyprocess>=0.5 in /Users/wesmadrigal/projects/graphreduce/venv/lib/python3.9/site-packages (from pexpect>4.3->ipython>=5.3.0->pyvis>=0.3.1->graphreduce) (0.7.0)
# Requirement already satisfied: wcwidth in /Users/wesmadrigal/projects/graphreduce/venv/lib/python3.9/site-packages (from prompt-toolkit!=3.0.0,!=3.0.1,<3.1.0,>=2.0.0->ipython>=5.3.0->pyvis>=0.3.1->graphreduce) (0.2.5)
# Requirement already satisfied: asttokens in /Users/wesmadrigal/projects/graphreduce/venv/lib/python3.9/site-packages (from stack-data->ipython>=5.3.0->pyvis>=0.3.1->graphreduce) (2.0.5)
# Requirement already satisfied: executing in /Users/wesmadrigal/projects/graphreduce/venv/lib/python3.9/site-packages (from stack-data->ipython>=5.3.0->pyvis>=0.3.1->graphreduce) (0.8.3)
# Requirement already satisfied: pure-eval in /Users/wesmadrigal/projects/graphreduce/venv/lib/python3.9/site-packages (from stack-data->ipython>=5.3.0->pyvis>=0.3.1->graphreduce) (0.2.2)
#
# [notice] A new release of pip available: 22.3.1 -> 23.3.1
# [notice] To update, run: pip install --upgrade pip

# %%
# !wget https://raw.githubusercontent.com/wesmadrigal/GraphReduce/master/examples/dat/cust.csv
# !wget https://raw.githubusercontent.com/wesmadrigal/GraphReduce/master/examples/dat/orders.csv
# !wget https://raw.githubusercontent.com/wesmadrigal/GraphReduce/master/examples/dat/notifications.csv
# !wget https://raw.githubusercontent.com/wesmadrigal/GraphReduce/master/examples/dat/order_events.csv
# !wget https://raw.githubusercontent.com/wesmadrigal/GraphReduce/master/examples/dat/notification_interactions.csv
# !wget https://raw.githubusercontent.com/wesmadrigal/GraphReduce/master/examples/dat/order_products.csv
# Out:
# --2023-11-01 22:13:02--  https://raw.githubusercontent.com/wesmadrigal/GraphReduce/master/examples/dat/cust.csv
# Resolving raw.githubusercontent.com (raw.githubusercontent.com)... 185.199.108.133, 185.199.109.133, 185.199.110.133, ...
# Connecting to raw.githubusercontent.com (raw.githubusercontent.com)|185.199.108.133|:443... connected.
# HTTP request sent, awaiting response... 200 OK
# Length: 21 [text/plain]
# Saving to: ‘cust.csv.3’
#
# cust.csv.3          100%[===================>]      21  --.-KB/s    in 0s
#
# 2023-11-01 22:13:03 (1.34 MB/s) - ‘cust.csv.3’ saved [21/21]
#
# --2023-11-01 22:13:03--  https://raw.githubusercontent.com/wesmadrigal/GraphReduce/master/examples/dat/orders.csv
# Resolving raw.githubusercontent.com (raw.githubusercontent.com)... 185.199.108.133, 185.199.109.133, 185.199.110.133, ...
# Connecting to raw.githubusercontent.com (raw.githubusercontent.com)|185.199.108.133|:443... connected.
# HTTP request sent, awaiting response... 200 OK
# Length: 159 [text/plain]
# Saving to: ‘orders.csv.1’
#
# orders.csv.1        100%[===================>]     159  --.-KB/s    in 0s
#
# 2023-11-01 22:13:03 (11.7 MB/s) - ‘orders.csv.1’ saved [159/159]
#
# --2023-11-01 22:13:03--  https://raw.githubusercontent.com/wesmadrigal/GraphReduce/master/examples/dat/notifications.csv
# Resolving raw.githubusercontent.com (raw.githubusercontent.com)... 185.199.108.133, 185.199.109.133, 185.199.110.133, ...
# Connecting to raw.githubusercontent.com (raw.githubusercontent.com)|185.199.108.133|:443... connected.
# HTTP request sent, awaiting response... 200 OK
# Length: 273 [text/plain]
# Saving to: ‘notifications.csv’
#
# notifications.csv   100%[===================>]     273  --.-KB/s    in 0s
#
# 2023-11-01 22:13:03 (10.8 MB/s) - ‘notifications.csv’ saved [273/273]
#
# --2023-11-01 22:13:03--  https://raw.githubusercontent.com/wesmadrigal/GraphReduce/master/examples/dat/order_events.csv
# Resolving raw.githubusercontent.com (raw.githubusercontent.com)... 185.199.108.133, 185.199.109.133, 185.199.110.133, ...
# Connecting to raw.githubusercontent.com (raw.githubusercontent.com)|185.199.108.133|:443... connected.
# HTTP request sent, awaiting response... 200 OK
# Length: 211 [text/plain]
# Saving to: ‘order_events.csv’
#
# order_events.csv    100%[===================>]     211  --.-KB/s    in 0s
#
# 2023-11-01 22:13:03 (14.4 MB/s) - ‘order_events.csv’ saved [211/211]
#
# --2023-11-01 22:13:04--  https://raw.githubusercontent.com/wesmadrigal/GraphReduce/master/examples/dat/notification_interactions.csv
# Resolving raw.githubusercontent.com (raw.githubusercontent.com)... 185.199.108.133, 185.199.109.133, 185.199.110.133, ...
# Connecting to raw.githubusercontent.com (raw.githubusercontent.com)|185.199.108.133|:443... connected.
# HTTP request sent, awaiting response... 200 OK
# Length: 442 [text/plain]
# Saving to: ‘notification_interactions.csv’
#
# notification_intera 100%[===================>]     442  --.-KB/s    in 0s
#
# 2023-11-01 22:13:04 (19.2 MB/s) - ‘notification_interactions.csv’ saved [442/442]
#
# --2023-11-01 22:13:04--  https://raw.githubusercontent.com/wesmadrigal/GraphReduce/master/examples/dat/order_products.csv
# Resolving raw.githubusercontent.com (raw.githubusercontent.com)... 185.199.108.133, 185.199.109.133, 185.199.110.133, ...
# Connecting to raw.githubusercontent.com (raw.githubusercontent.com)|185.199.108.133|:443... connected.
# HTTP request sent, awaiting response... 200 OK
# Length: 126 [text/plain]
# Saving to: ‘order_products.csv’
#
# order_products.csv  100%[===================>]     126  --.-KB/s    in 0s
#
# 2023-11-01 22:13:04 (6.68 MB/s) - ‘order_products.csv’ saved [126/126]

# %%
# !mkdir dat
# Out:
# mkdir: dat: File exists

# %%
# !mv cust.csv dat/
# !mv orders.csv dat/
# !mv notifications.csv dat/
# !mv order_events.csv dat/
# !mv notification_interactions.csv dat/
# !mv order_products.csv dat/
# Out:
# mv: cust.csv: No such file or directory
# mv: orders.csv: No such file or directory

# %%
import datetime

import pandas as pd

from graphreduce.node import GraphReduceNode
from graphreduce.graph_reduce import GraphReduce
from graphreduce.enum import ComputeLayerEnum, PeriodUnit

# %%
# In this notebook we'll look at constructing a slightly larger
# graph reduce pipeline.  This time we'll use 7 tables.

# %%
class CustomerNode(GraphReduceNode):
    def do_annotate(self):
        self.df[self.colabbr('name_length')] = self.df[self.colabbr('name')].apply(lambda x: len(x))
    
    def do_filters(self):
        pass
    
    def do_normalize(self):
        pass
    
    def do_post_join_annotate(self):
        pass
    
    def do_reduce(self, reduce_key, *args, **kwargs):
        pass
    
    def do_labels(self, reduce_key, *args, **kwargs):
        pass

# %%
class OrderNode(GraphReduceNode):
    def do_annotate(self):
        pass
    
    def do_filters(self):
        pass
    
    def do_normalize(self):
        pass
    
    def do_post_join_annotate(self):
        pass
    
    def do_reduce(self, reduce_key):
        return self.prep_for_features().groupby(self.colabbr(reduce_key)).agg(
            **{
                self.colabbr(f'{self.pk}_count') : pd.NamedAgg(column=self.colabbr(self.pk), aggfunc='count'),
                self.colabbr(f'amount_sum'): pd.NamedAgg(column=self.colabbr('amount'), aggfunc='sum')
            }
        ).reset_index()
    
    def do_labels(self, reduce_key):
        return self.prep_for_labels().groupby(self.colabbr(reduce_key)).agg(
            **{
                self.colabbr(f'{self.pk}_had_order') : pd.NamedAgg(column=self.colabbr(self.pk), aggfunc='count')
            }
        ).reset_index()

# %%
class OrderProductNode(GraphReduceNode):
    def do_annotate(self):
        pass
    
    def do_filters(self):
        pass
    
    def do_normalize(self):
        pass
    
    def do_post_join_annotate(self):
        pass
    
    def do_reduce(self, reduce_key):
        return self.prep_for_features().groupby(self.colabbr(reduce_key)).agg(
            **{
                self.colabbr(f'{self.pk}_count') : pd.NamedAgg(column=self.colabbr(self.pk), aggfunc='count')
            }
        ).reset_index()
    
    def do_labels(self, key):
        pass

# %%
class OrderEventNode(GraphReduceNode):
    def do_annotate(self):
        pass
    
    def do_filters(self):
        pass
    
    def do_normalize(self):
        pass
    
    def do_post_join_annotate(self):
        pass
    
    def do_reduce(self, reduce_key, *args, **kwargs):
        return self.prep_for_features().groupby(self.colabbr(reduce_key)).agg(
            **{
                self.colabbr(f'{self.pk}_count') : pd.NamedAgg(column=self.colabbr(self.pk), aggfunc='count')
            }
        ).reset_index()
    
    def do_labels(self, key):
        pass

# %%
class NotificationNode(GraphReduceNode):
    def do_annotate(self):
        pass
    
    def do_filters(self):
        pass
    
    def do_normalize(self):
        pass

    def do_post_join_annotate(self):
        pass
    
    def do_reduce(self, reduce_key, *args, **kwargs):
        df = self.prep_for_features().groupby(self.colabbr(reduce_key)).agg(
            **{
                self.colabbr(f'{self.pk}_count') : pd.NamedAgg(column=self.colabbr(self.pk), aggfunc='count'),
                #'ni_num_notification_interactions' : pd.NamedAgg(column='ni_num_interactions', aggfunc='sum')
            }
        ).reset_index()
        return df
        
    
    def do_labels(self, key):
        pass

# %%
class NotificationInteractionNode(GraphReduceNode):
    def do_annotate(self):
        self.df[self.colabbr(self.date_key)] = self.df[self.colabbr(self.date_key)].apply(
            lambda x: datetime.datetime.strptime(x, '%Y-%m-%d'))
    
    def do_filters(self):
        pass
    
    def do_normalize(self):
        pass
    
    def do_post_join_annotate(self):
        pass
    
    def do_reduce(self, 
                  reduce_key : str,
                  additional_agg : dict = {}
                 ):
        
        return self.prep_for_features().groupby(self.colabbr(reduce_key)).agg(
            **{
                self.colabbr(f'{self.pk}_counts') : pd.NamedAgg(column=self.colabbr(self.pk), aggfunc='count'),
                self.colabbr(f'{self.pk}_min') : pd.NamedAgg(column=self.colabbr(self.pk), aggfunc='min'),
                self.colabbr(f'{self.pk}_min'): pd.NamedAgg(column=self.colabbr(self.pk), aggfunc='max'),
                self.colabbr(f'num_interactions') : pd.NamedAgg(column=self.colabbr(self.pk), aggfunc='count'),

            }
        ).reset_index()
    
    def do_labels(self, reduce_key, *args, **kwargs):
        label_df = self.prep_for_labels().groupby(self.colabbr(reduce_key)).agg(
            **{
                # add a label / target for a model predicting the number of interactions
                self.colabbr(f'{self.pk}_num_interactions') : pd.NamedAgg(column=self.colabbr(self.pk), aggfunc='count'),
            }
        ).reset_index()
        return label_df

# %%
class ProductNode(GraphReduceNode):
    def do_annotate(self):
        pass
    
    def do_filters(self):
        pass
    
    def do_normalize(self):
        pass
    
    def do_post_join_annotate(self):
        pass
    
    def do_reduce(self, 
                  reduce_key : str,
                 ):
        pass
    
    def do_labels(self, reduce_key, *args, **kwargs):
        pass

# %%
cust = CustomerNode(pk='id', prefix='cust',fpath='dat/cust.csv', fmt='csv')
order = OrderNode(pk='id', prefix='order', fpath='dat/orders.csv', fmt='csv', date_key='ts')
order_event = OrderEventNode(pk='id', prefix='oe',fpath='dat/order_events.csv', fmt='csv')
order_product = OrderProductNode(pk='id', prefix='op',fpath='dat/order_products.csv', fmt='csv')
notification = NotificationNode(pk='id', prefix='no', fpath='dat/notifications.csv', fmt='csv', date_key='ts')
notification_interaction = NotificationInteractionNode(pk='id', prefix='ni',fpath='dat/notification_interactions.csv', fmt='csv',
                                                      date_key='ts')
product = ProductNode(pk='id',prefix='prod',fpath='dat/products.csv',fmt='csv')
# Out:
# 2023-10-31 11:00:32 [warning  ] no `date_key` set for <GraphReduceNode: fpath=dat/cust.csv fmt=csv>
# 2023-10-31 11:00:32 [warning  ] no `date_key` set for <GraphReduceNode: fpath=dat/order_events.csv fmt=csv>
# 2023-10-31 11:00:32 [warning  ] no `date_key` set for <GraphReduceNode: fpath=dat/order_products.csv fmt=csv>
# 2023-10-31 11:00:32 [warning  ] no `date_key` set for <GraphReduceNode: fpath=dat/products.csv fmt=csv>

# %%
gr = GraphReduce(
    name='odsc_example_2',
    parent_node=cust,
    cut_date=datetime.datetime(2023, 5, 6),
    compute_period_val=365,
    compute_period_unit=PeriodUnit.day,
    compute_layer=ComputeLayerEnum.pandas,
    has_labels=False,
    label_period_val=30,
    label_period_unit=PeriodUnit.day
)

# %%
gr.add_node(cust)
gr.add_node(order)
gr.add_node(order_event)
gr.add_node(order_product)
gr.add_node(notification)
gr.add_node(notification_interaction)
gr.add_node(product)

# %%
gr.add_entity_edge(
    parent_node=cust,
    relation_node=order,
    parent_key='id',
    relation_key='customer_id',
    reduce=True
)

gr.add_entity_edge(
    parent_node=order,
    relation_node=order_product,
    parent_key='id',
    relation_key='order_id',
    reduce=True
)

gr.add_entity_edge(
    parent_node=order,
    relation_node=order_event,
    parent_key='id',
    relation_key='order_id',
    reduce=True
)


gr.add_entity_edge(
    parent_node=cust,
    relation_node=notification,
    parent_key='id',
    relation_key='customer_id',
    reduce=True
)

gr.add_entity_edge(
    parent_node=notification,
    relation_node=notification_interaction,
    parent_key='id',
    relation_key='notification_id',
    reduce=True
)

gr.add_entity_edge(
    parent_node=order_product,
    relation_node=product,
    parent_key='product_id',
    relation_key='id',
    reduce=True
)

# %%
gr.plot_graph('odsc_graph2.html')
# Out:
# 2023-10-31 11:01:41 [info     ] plotted graph at odsc_graph2.html

# %%
# !open odsc_graph2.html

# %%
gr.do_transformations()
# Out:
# 2023-10-31 11:02:18 [info     ] hydrating graph attributes
# 2023-10-31 11:02:18 [info     ] hydrating attributes for CustomerNode
# 2023-10-31 11:02:18 [info     ] hydrating attributes for OrderNode
# 2023-10-31 11:02:18 [info     ] hydrating attributes for OrderEventNode
# 2023-10-31 11:02:18 [info     ] hydrating attributes for OrderProductNode
# 2023-10-31 11:02:18 [info     ] hydrating attributes for NotificationNode
# 2023-10-31 11:02:18 [info     ] hydrating attributes for NotificationInteractionNode
# 2023-10-31 11:02:18 [info     ] hydrating attributes for ProductNode
# 2023-10-31 11:02:18 [info     ] hydrating graph data
# 2023-10-31 11:02:18 [info     ] checking for prefix uniqueness
# 2023-10-31 11:02:18 [info     ] running filters, normalize, and annotations for <GraphReduceNode: fpath=dat/cust.csv fmt=csv>
# 2023-10-31 11:02:18 [info     ] running filters, normalize, and annotations for <GraphReduceNode: fpath=dat/orders.csv fmt=csv>
# 2023-10-31 11:02:18 [info     ] running filters, normalize, and annotations for <GraphReduceNode: fpath=dat/order_events.csv fmt=csv>
# 2023-10-31 11:02:18 [info     ] running filters, normalize, and annotations for <GraphReduceNode: fpath=dat/order_products.csv fmt=csv>
# 2023-10-31 11:02:18 [info     ] running filters, normalize, and annotations for <GraphReduceNode: fpath=dat/notifications.csv fmt=csv>
# 2023-10-31 11:02:18 [info     ] running filters, normalize, and annotations for <GraphReduceNode: fpath=dat/notification_interactions.csv fmt=csv>
# 2023-10-31 11:02:18 [info     ] running filters, normalize, and annotations for <GraphReduceNode: fpath=dat/products.csv fmt=csv>
# 2023-10-31 11:02:18 [info     ] depth-first traversal through the graph from source: <GraphReduceNode: fpath=dat/cust.csv fmt=csv>
# 2023-10-31 11:02:18 [info     ] reducing relation <GraphReduceNode: fpath=dat/notification_interactions.csv fmt=csv>
# 2023-10-31 11:02:18 [info     ] joining <GraphReduceNode: fpath=dat/notification_interactions.csv fmt=csv> to <GraphReduceNode: fpath=dat/notifications.csv fmt=csv>
# 2023-10-31 11:02:18 [info     ] reducing relation <GraphReduceNode: fpath=dat/notifications.csv fmt=csv>
# 2023-10-31 11:02:18 [info     ] joining <GraphReduceNode: fpath=dat/notifications.csv fmt=csv> to <GraphReduceNode: fpath=dat/cust.csv fmt=csv>
# 2023-10-31 11:02:18 [info     ] reducing relation <GraphReduceNode: fpath=dat/order_events.csv fmt=csv>
# 2023-10-31 11:02:18 [info     ] joining <GraphReduceNode: fpath=dat/order_events.csv fmt=csv> to <GraphReduceNode: fpath=dat/orders.csv fmt=csv>
# 2023-10-31 11:02:18 [info     ] reducing relation <GraphReduceNode: fpath=dat/products.csv fmt=csv>
# 2023-10-31 11:02:18 [info     ] joining <GraphReduceNode: fpath=dat/products.csv fmt=csv> to <GraphReduceNode: fpath=dat/order_products.csv fmt=csv>
# 2023-10-31 11:02:18 [info     ] reducing relation <GraphReduceNode: fpath=dat/order_products.csv fmt=csv>
# 2023-10-31 11:02:18 [info     ] joining <GraphReduceNode: fpath=dat/order_products.csv fmt=csv> to <GraphReduceNode: fpath=dat/orders.csv fmt=csv>
# 2023-10-31 11:02:18 [info     ] reducing relation <GraphReduceNode: fpath=dat/orders.csv fmt=csv>
# 2023-10-31 11:02:18 [info     ] joining <GraphReduceNode: fpath=dat/orders.csv fmt=csv> to <GraphReduceNode: fpath=dat/cust.csv fmt=csv>

# %% [raw]
# gr.parent_node.df

# %%
gr.parent_node.df
# Out:
#    cust_id cust_name  cust_name_length  no_customer_id  no_id_count  \
# 0        1       wes                 3               1            3
# 1        2      john                 4               2            3
#
#    order_customer_id  order_id_count  order_amount_sum
# 0                NaN             NaN               NaN
# 1                2.0             2.0             250.0

# %%
# let's aggregate all of the features by
# using dynamic propagation

# %%
cust = CustomerNode(pk='id', prefix='cust',fpath='dat/cust.csv', fmt='csv')
order = OrderNode(pk='id', prefix='order', fpath='dat/orders.csv', fmt='csv', date_key='ts')
order_event = OrderEventNode(pk='id', prefix='oe',fpath='dat/order_events.csv', fmt='csv')
order_product = OrderProductNode(pk='id', prefix='op',fpath='dat/order_products.csv', fmt='csv')
notification = NotificationNode(pk='id', prefix='no', fpath='dat/notifications.csv', fmt='csv', date_key='ts')
notification_interaction = NotificationInteractionNode(pk='id', prefix='ni',fpath='dat/notification_interactions.csv', fmt='csv',
                                                      date_key='ts')
product = ProductNode(pk='id',prefix='prod',fpath='dat/products.csv',fmt='csv')


gr = GraphReduce(
    name='odsc_example_2',
    parent_node=cust,
    cut_date=datetime.datetime(2023, 5, 6),
    compute_period_val=365,
    compute_period_unit=PeriodUnit.day,
    compute_layer=ComputeLayerEnum.pandas,
    has_labels=True,
    label_period_val=30,
    label_period_unit=PeriodUnit.day,
    dynamic_propagation=True
)

gr.add_node(cust)
gr.add_node(order)
gr.add_node(order_event)
gr.add_node(order_product)
gr.add_node(notification)
gr.add_node(notification_interaction)
gr.add_node(product)

gr.add_entity_edge(
    parent_node=cust,
    relation_node=order,
    parent_key='id',
    relation_key='customer_id',
    reduce=True
)

gr.add_entity_edge(
    parent_node=order,
    relation_node=order_product,
    parent_key='id',
    relation_key='order_id',
    reduce=True
)

gr.add_entity_edge(
    parent_node=order,
    relation_node=order_event,
    parent_key='id',
    relation_key='order_id',
    reduce=True
)


gr.add_entity_edge(
    parent_node=cust,
    relation_node=notification,
    parent_key='id',
    relation_key='customer_id',
    reduce=True
)

gr.add_entity_edge(
    parent_node=notification,
    relation_node=notification_interaction,
    parent_key='id',
    relation_key='notification_id',
    reduce=True
)

gr.add_entity_edge(
    parent_node=order_product,
    relation_node=product,
    parent_key='product_id',
    relation_key='id',
    reduce=True
)
# Out:
# 2023-10-31 11:03:34 [warning  ] no `date_key` set for <GraphReduceNode: fpath=dat/cust.csv fmt=csv>
# 2023-10-31 11:03:34 [warning  ] no `date_key` set for <GraphReduceNode: fpath=dat/order_events.csv fmt=csv>
# 2023-10-31 11:03:34 [warning  ] no `date_key` set for <GraphReduceNode: fpath=dat/order_products.csv fmt=csv>
# 2023-10-31 11:03:34 [warning  ] no `date_key` set for <GraphReduceNode: fpath=dat/products.csv fmt=csv>

# %%
gr.do_transformations()
# Out:
# 2023-10-31 11:03:36 [info     ] hydrating graph attributes
# 2023-10-31 11:03:36 [info     ] hydrating attributes for CustomerNode
# 2023-10-31 11:03:36 [info     ] hydrating attributes for OrderNode
# 2023-10-31 11:03:36 [info     ] hydrating attributes for OrderEventNode
# 2023-10-31 11:03:36 [info     ] hydrating attributes for OrderProductNode
# 2023-10-31 11:03:36 [info     ] hydrating attributes for NotificationNode
# 2023-10-31 11:03:36 [info     ] hydrating attributes for NotificationInteractionNode
# 2023-10-31 11:03:36 [info     ] hydrating attributes for ProductNode
# 2023-10-31 11:03:36 [info     ] hydrating graph data
# 2023-10-31 11:03:36 [info     ] checking for prefix uniqueness
# 2023-10-31 11:03:36 [info     ] running filters, normalize, and annotations for <GraphReduceNode: fpath=dat/cust.csv fmt=csv>
# 2023-10-31 11:03:36 [info     ] running filters, normalize, and annotations for <GraphReduceNode: fpath=dat/orders.csv fmt=csv>
# 2023-10-31 11:03:36 [info     ] running filters, normalize, and annotations for <GraphReduceNode: fpath=dat/order_events.csv fmt=csv>
# 2023-10-31 11:03:36 [info     ] running filters, normalize, and annotations for <GraphReduceNode: fpath=dat/order_products.csv fmt=csv>
# 2023-10-31 11:03:36 [info     ] running filters, normalize, and annotations for <GraphReduceNode: fpath=dat/notifications.csv fmt=csv>
# 2023-10-31 11:03:36 [info     ] running filters, normalize, and annotations for <GraphReduceNode: fpath=dat/notification_interactions.csv fmt=csv>
# 2023-10-31 11:03:36 [info     ] running filters, normalize, and annotations for <GraphReduceNode: fpath=dat/products.csv fmt=csv>
# 2023-10-31 11:03:36 [info     ] depth-first traversal through the graph from source: <GraphReduceNode: fpath=dat/cust.csv fmt=csv>
# 2023-10-31 11:03:36 [info     ] reducing relation <GraphReduceNode: fpath=dat/notification_interactions.csv fmt=csv>
# 2023-10-31 11:03:36 [info     ] doing dynamic propagation on node <GraphReduceNode: fpath=dat/notification_interactions.csv fmt=csv>
# 2023-10-31 11:03:36 [info     ] joining <GraphReduceNode: fpath=dat/notification_interactions.csv fmt=csv> to <GraphReduceNode: fpath=dat/notifications.csv fmt=csv>
# 2023-10-31 11:03:36 [info     ] computed labels for <GraphReduceNode: fpath=dat/notification_interactions.csv fmt=csv>
# 2023-10-31 11:03:36 [info     ] reducing relation <GraphReduceNode: fpath=dat/notifications.csv fmt=csv>
# 2023-10-31 11:03:36 [info     ] doing dynamic propagation on node <GraphReduceNode: fpath=dat/notifications.csv fmt=csv>
# 2023-10-31 11:03:36 [info     ] joining <GraphReduceNode: fpath=dat/notifications.csv fmt=csv> to <GraphReduceNode: fpath=dat/cust.csv fmt=csv>
# 2023-10-31 11:03:36 [info     ] computed labels for <GraphReduceNode: fpath=dat/notifications.csv fmt=csv>
# 2023-10-31 11:03:36 [info     ] reducing relation <GraphReduceNode: fpath=dat/order_events.csv fmt=csv>
# 2023-10-31 11:03:36 [info     ] doing dynamic propagation on node <GraphReduceNode: fpath=dat/order_events.csv fmt=csv>
# 2023-10-31 11:03:36 [info     ] joining <GraphReduceNode: fpath=dat/order_events.csv fmt=csv> to <GraphReduceNode: fpath=dat/orders.csv fmt=csv>
# 2023-10-31 11:03:36 [info     ] computed labels for <GraphReduceNode: fpath=dat/order_events.csv fmt=csv>
# 2023-10-31 11:03:36 [info     ] reducing relation <GraphReduceNode: fpath=dat/products.csv fmt=csv>
# 2023-10-31 11:03:36 [info     ] doing dynamic propagation on node <GraphReduceNode: fpath=dat/products.csv fmt=csv>
# 2023-10-31 11:03:36 [info     ] joining <GraphReduceNode: fpath=dat/products.csv fmt=csv> to <GraphReduceNode: fpath=dat/order_products.csv fmt=csv>
# 2023-10-31 11:03:36 [info     ] computed labels for <GraphReduceNode: fpath=dat/products.csv fmt=csv>
# 2023-10-31 11:03:36 [info     ] reducing relation <GraphReduceNode: fpath=dat/order_products.csv fmt=csv>
# 2023-10-31 11:03:36 [info     ] doing dynamic propagation on node <GraphReduceNode: fpath=dat/order_products.csv fmt=csv>
# 2023-10-31 11:03:36 [info     ] joining <GraphReduceNode: fpath=dat/order_products.csv fmt=csv> to <GraphReduceNode: fpath=dat/orders.csv fmt=csv>
# 2023-10-31 11:03:36 [info     ] computed labels for <GraphReduceNode: fpath=dat/order_products.csv fmt=csv>
# 2023-10-31 11:03:36 [info     ] reducing relation <GraphReduceNode: fpath=dat/orders.csv fmt=csv>
# 2023-10-31 11:03:36 [info     ] doing dynamic propagation on node <GraphReduceNode: fpath=dat/orders.csv fmt=csv>
# 2023-10-31 11:03:36 [info     ] joining <GraphReduceNode: fpath=dat/orders.csv fmt=csv> to <GraphReduceNode: fpath=dat/cust.csv fmt=csv>
# 2023-10-31 11:03:36 [info     ] computed labels for <GraphReduceNode: fpath=dat/orders.csv fmt=csv>

# %%
gr.parent_node.df
# Out:
#    cust_id cust_name  cust_name_length  no_customer_id  no_id_count  \
# 0        1       wes                 3               1            3
# 1        2      john                 4               2            3
#
#    no_id_min  no_id_max  no_id_sum  no_customer_id_min  no_customer_id_max  \
# 0        101        103        306                   1                   1
# 1        107        109        324                   2                   2
#
#    ...  prod_id_sum_max_min prod_id_sum_max_max  prod_id_sum_max_sum  \
# 0  ...                  NaN                 NaN                  NaN
# 1  ...                  4.0                 4.0                  8.0
#
#    prod_id_sum_sum_min  prod_id_sum_sum_max  prod_id_sum_sum_sum  \
# 0                  NaN                  NaN                  NaN
# 1                 10.0                 10.0                 20.0
#
#    prod_name_first_first_first  prod_category_first_first_first  \
# 0                          NaN                              NaN
# 1                       butter                             food
#
#    order_customer_id_dupe  order_id_had_order
# 0                     1.0                 2.0
# 1                     NaN                 NaN
#
# [2 rows x 176 columns]

# %%
pd.set_option('display.max_columns', 200)

# %%
gr.parent_node.df
# Out:
#    cust_id cust_name  cust_name_length  no_customer_id  no_id_count  \
# 0        1       wes                 3               1            3
# 1        2      john                 4               2            3
#
#    no_id_min  no_id_max  no_id_sum  no_customer_id_min  no_customer_id_max  \
# 0        101        103        306                   1                   1
# 1        107        109        324                   2                   2
#
#    no_customer_id_sum no_ts_first  ni_notification_id_min  \
# 0                   3  2022-08-05                   101.0
# 1                   6  2022-09-05                     NaN
#
#    ni_notification_id_max  ni_notification_id_sum  ni_id_counts_min  \
# 0                   103.0                   306.0               1.0
# 1                     NaN                     0.0               NaN
#
#    ni_id_counts_max  ni_id_counts_sum  ni_id_min_min  ni_id_min_max  \
# 0               3.0               7.0         1002.0         1006.0
# 1               NaN               0.0            NaN            NaN
#
#    ni_id_min_sum  ni_num_interactions_min  ni_num_interactions_max  \
# 0         3013.0                      1.0                      3.0
# 1            0.0                      NaN                      NaN
#
#    ni_num_interactions_sum  ni_id_min_dupe_min  ni_id_min_dupe_max  \
# 0                      7.0              1000.0              1006.0
# 1                      0.0                 NaN                 NaN
#
#    ni_id_min_dupe_sum  ni_id_max_min  ni_id_max_max  ni_id_max_sum  \
# 0              3009.0         1002.0         1006.0         3013.0
# 1                 0.0            NaN            NaN            0.0
#
#    ni_id_sum_min  ni_id_sum_max  ni_id_sum_sum  ni_notification_id_min_min  \
# 0         1006.0         3012.0         7021.0                       101.0
# 1            NaN            NaN            0.0                         NaN
#
#    ni_notification_id_min_max  ni_notification_id_min_sum  \
# 0                       103.0                       306.0
# 1                         NaN                         0.0
#
#    ni_notification_id_max_min  ni_notification_id_max_max  \
# 0                       101.0                       103.0
# 1                         NaN                         NaN
#
#    ni_notification_id_max_sum  ni_notification_id_sum_min  \
# 0                       306.0                       103.0
# 1                         0.0                         NaN
#
#    ni_notification_id_sum_max  ni_notification_id_sum_sum  \
# 0                       306.0                       712.0
# 1                         NaN                         0.0
#
#    ni_interaction_type_id_min_min  ni_interaction_type_id_min_max  \
# 0                          1500.0                          1500.0
# 1                             NaN                             NaN
#
#    ni_interaction_type_id_min_sum  ni_interaction_type_id_max_min  \
# 0                          4500.0                          1500.0
# 1                             0.0                             NaN
#
#    ni_interaction_type_id_max_max  ni_interaction_type_id_max_sum  \
# 0                          1700.0                          4900.0
# 1                             NaN                             0.0
#
#    ni_interaction_type_id_sum_min  ni_interaction_type_id_sum_max  \
# 0                          1500.0                          4800.0
# 1                             NaN                             NaN
#
#    ni_interaction_type_id_sum_sum  ni_notification_id_dupe_min  \
# 0                         11100.0                        103.0
# 1                             0.0                        107.0
#
#    ni_notification_id_dupe_max  ni_notification_id_dupe_sum  \
# 0                        103.0                        103.0
# 1                        107.0                        107.0
#
#    ni_id_num_interactions_min  ni_id_num_interactions_max  \
# 0                         1.0                         1.0
# 1                         1.0                         1.0
#
#    ni_id_num_interactions_sum  order_customer_id  order_id_count  \
# 0                         1.0                NaN             NaN
# 1                         1.0                2.0             2.0
#
#    order_amount_sum  order_id_min  order_id_max  order_id_sum  \
# 0               NaN           NaN           NaN           NaN
# 1             250.0           3.0           4.0           7.0
#
#    order_customer_id_min  order_customer_id_max  order_customer_id_sum  \
# 0                    NaN                    NaN                    NaN
# 1                    2.0                    2.0                    4.0
#
#   order_ts_first  order_amount_min  order_amount_max  order_amount_sum_dupe  \
# 0            NaN               NaN               NaN                    NaN
# 1     2023-01-01             100.0             150.0                  250.0
#
#    oe_order_id_min  oe_order_id_max  oe_order_id_sum  oe_id_count_min  \
# 0              NaN              NaN              NaN              NaN
# 1              3.0              3.0              3.0              6.0
#
#    oe_id_count_max  oe_id_count_sum  oe_id_min_min  oe_id_min_max  \
# 0              NaN              NaN            NaN            NaN
# 1              6.0              6.0           21.0           21.0
#
#    oe_id_min_sum  oe_id_max_min  oe_id_max_max  oe_id_max_sum  oe_id_sum_min  \
# 0            NaN            NaN            NaN            NaN            NaN
# 1           21.0           26.0           26.0           26.0          141.0
#
#    oe_id_sum_max  oe_id_sum_sum  oe_order_id_min_min  oe_order_id_min_max  \
# 0            NaN            NaN                  NaN                  NaN
# 1          141.0          141.0                  3.0                  3.0
#
#    oe_order_id_min_sum  oe_order_id_max_min  oe_order_id_max_max  \
# 0                  NaN                  NaN                  NaN
# 1                  3.0                  3.0                  3.0
#
#    oe_order_id_max_sum  oe_order_id_sum_min  oe_order_id_sum_max  \
# 0                  NaN                  NaN                  NaN
# 1                  3.0                 18.0                 18.0
#
#    oe_order_id_sum_sum  oe_event_id_min_min  oe_event_id_min_max  \
# 0                  NaN                  NaN                  NaN
# 1                 18.0                 21.0                 21.0
#
#    oe_event_id_min_sum  oe_event_id_max_min  oe_event_id_max_max  \
# 0                  NaN                  NaN                  NaN
# 1                 21.0                 26.0                 26.0
#
#    oe_event_id_max_sum  oe_event_id_sum_min  oe_event_id_sum_max  \
# 0                  NaN                  NaN                  NaN
# 1                 26.0                141.0                141.0
#
#    oe_event_id_sum_sum  op_order_id_min  op_order_id_max  op_order_id_sum  \
# 0                  NaN              NaN              NaN              NaN
# 1                141.0              3.0              4.0              7.0
#
#    op_id_count_min  op_id_count_max  op_id_count_sum  op_id_min_min  \
# 0              NaN              NaN              NaN            NaN
# 1              4.0              4.0              8.0            9.0
#
#    op_id_min_max  op_id_min_sum  op_id_max_min  op_id_max_max  op_id_max_sum  \
# 0            NaN            NaN            NaN            NaN            NaN
# 1           13.0           22.0           12.0           16.0           28.0
#
#    op_id_sum_min  op_id_sum_max  op_id_sum_sum  op_order_id_min_min  \
# 0            NaN            NaN            NaN                  NaN
# 1           42.0           58.0          100.0                  3.0
#
#    op_order_id_min_max  op_order_id_min_sum  op_order_id_max_min  \
# 0                  NaN                  NaN                  NaN
# 1                  4.0                  7.0                  3.0
#
#    op_order_id_max_max  op_order_id_max_sum  op_order_id_sum_min  \
# 0                  NaN                  NaN                  NaN
# 1                  4.0                  7.0                 12.0
#
#    op_order_id_sum_max  op_order_id_sum_sum  op_product_id_min_min  \
# 0                  NaN                  NaN                    NaN
# 1                 16.0                 28.0                    1.0
#
#    op_product_id_min_max  op_product_id_min_sum  op_product_id_max_min  \
# 0                    NaN                    NaN                    NaN
# 1                    1.0                    2.0                    4.0
#
#    op_product_id_max_max  op_product_id_max_sum  op_product_id_sum_min  \
# 0                    NaN                    NaN                    NaN
# 1                    4.0                    8.0                   10.0
#
#    op_product_id_sum_max  op_product_id_sum_sum  prod_id_min_min  \
# 0                    NaN                    NaN              NaN
# 1                   10.0                   20.0              1.0
#
#    prod_id_min_max  prod_id_min_sum  prod_id_max_min  prod_id_max_max  \
# 0              NaN              NaN              NaN              NaN
# 1              1.0              2.0              4.0              4.0
#
#    prod_id_max_sum  prod_id_sum_min  prod_id_sum_max  prod_id_sum_sum  \
# 0              NaN              NaN              NaN              NaN
# 1              8.0             10.0             10.0             20.0
#
#    prod_id_min_min_min  prod_id_min_min_max  prod_id_min_min_sum  \
# 0                  NaN                  NaN                  NaN
# 1                  1.0                  1.0                  2.0
#
#    prod_id_min_max_min  prod_id_min_max_max  prod_id_min_max_sum  \
# 0                  NaN                  NaN                  NaN
# 1                  4.0                  4.0                  8.0
#
#    prod_id_min_sum_min  prod_id_min_sum_max  prod_id_min_sum_sum  \
# 0                  NaN                  NaN                  NaN
# 1                 10.0                 10.0                 20.0
#
#    prod_id_max_min_min  prod_id_max_min_max  prod_id_max_min_sum  \
# 0                  NaN                  NaN                  NaN
# 1                  1.0                  1.0                  2.0
#
#    prod_id_max_max_min  prod_id_max_max_max  prod_id_max_max_sum  \
# 0                  NaN                  NaN                  NaN
# 1                  4.0                  4.0                  8.0
#
#    prod_id_max_sum_min  prod_id_max_sum_max  prod_id_max_sum_sum  \
# 0                  NaN                  NaN                  NaN
# 1                 10.0                 10.0                 20.0
#
#    prod_id_sum_min_min  prod_id_sum_min_max  prod_id_sum_min_sum  \
# 0                  NaN                  NaN                  NaN
# 1                  1.0                  1.0                  2.0
#
#    prod_id_sum_max_min  prod_id_sum_max_max  prod_id_sum_max_sum  \
# 0                  NaN                  NaN                  NaN
# 1                  4.0                  4.0                  8.0
#
#    prod_id_sum_sum_min  prod_id_sum_sum_max  prod_id_sum_sum_sum  \
# 0                  NaN                  NaN                  NaN
# 1                 10.0                 10.0                 20.0
#
#   prod_name_first_first_first prod_category_first_first_first  \
# 0                         NaN                             NaN
# 1                      butter                            food
#
#    order_customer_id_dupe  order_id_had_order
# 0                     1.0                 2.0
# 1                     NaN                 NaN
